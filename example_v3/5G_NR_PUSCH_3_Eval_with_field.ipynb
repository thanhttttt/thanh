# %%
"""Run two below lines to get my_abc module"""
# !git clone https://github.com/thanhttttt/thanh.git
# !pip install -r /content/thanh/requirements.txt
"""Run two below lines to drive"""
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# 'Run two below lines to drive'

# %% [markdown]
# # Import

# %%
import os
if os.getenv("CUDA_VISIBLE_DEVICES") is None:
    gpu_num = 0 # Use "" to use the CPU
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


import sys
sys.path.append('../')
sys.path.append('/content/thanh/')
sys.path.append('../thanh/')
import sionna

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')

sionna.config.seed = 42 # Set seed for reproducible random number generation

# Load the required Sionna components
from sionna.nr.my_abc import *

# %%
# Đường dẫn đến thư mục chứa các file config
config_dir = "/workspaces/thanh/data_field/"

filtered_dump_fail_files = []
filtered_dump_pass_files = []

# Duyệt qua các file trong thư mục
for root, dirs, files in os.walk(config_dir):
    for name in files:
        filename = f'{root}/{name}'
        if filename.endswith("_cfg.txt"):  # Chỉ xét các file config
            file_path = os.path.join(config_dir, filename)
            
            with open(file_path, "r", encoding="utf-8") as file:
                content = file.read()

            DmrsTypeAPos = re.search(r"ue\{1\}\.DmrsTypeAPosition\s*=\s*(\d+)", content)
            DmrsAddPos = re.search(r"ue\{1\}\.DmrsAdditionalPosition\s*=\s*(\d+)", content)
            Mcs = re.search(r"ue\{1\}\.Mcs\s*=\s*(\d+)", content)
            Nrb = re.search(r"ue\{1\}\.NPrb\s*=\s*(\d+)", content)

            if DmrsTypeAPos and DmrsAddPos and Mcs and Nrb:
                DmrsTypeAPos = int(DmrsTypeAPos.group(1))
                DmrsAddPos = int(DmrsAddPos.group(1))
                Mcs = int(Mcs.group(1))
                Nrb = int(Nrb.group(1))

                # Kiểm tra điều kiện
                if DmrsTypeAPos == 3 and DmrsAddPos == 1 and Mcs in {3, 5, 6, 7, 8, 9} and Nrb >= 4:
                    filename = filename[:-len('_cfg.txt')]
                    if 'dump_fail' in filename:
                        filtered_dump_fail_files.append(filename)
                    elif 'dump_pass' in filename:
                        filtered_dump_pass_files.append(filename)

print("Các file thỏa mãn điều kiện:")
print('dump fail: ', len(filtered_dump_fail_files), 'files', '\ndump pass:', len(filtered_dump_pass_files), 'files')
# Out:
# Các file thỏa mãn điều kiện:
# dump fail:  52 files
# dump pass: 181 files

# %%
_model = CustomNeuralReceiver(training = False)
inputs = tf.zeros([1,48,14,18])
_model(inputs)
load_weights(_model, '../weight_4RB_batchsize_128_UMI_dynamic_config_85k_samples.pkl');
# Out:
# Loaded pretrained weights from ../weight_4RB_batchsize_128_UMI_dynamic_config_85k_samples.pkl

# %%
channel_model = CDL(model = 'A',
                            delay_spread = 150*1e-9,
                            carrier_frequency = CARRIER_FREQUENCY,
                            ut_array = Ue_Antenna,
                            bs_array = Gnb_AntennaArray,
                            direction = 'uplink',
                            min_speed = 1,
                            max_speed = 1)

# %%
ls_counter = 0
nn_counter = 0

for n, filename in enumerate(filtered_dump_fail_files):
    cfg_path = f'{filename}_cfg.txt'
    data_path = f'{filename}_freq.bin'

    caseInfo, sysInfo, ueInfo, chcfg, auxInfo = config_parser(cfg_path)
    freqIQ = data_reader(data_path, (sysInfo['NRxAnt'], 14, sysInfo['BwpNRb']*12))
    ueIQ = tf.constant(freqIQ[None, None, :, :, ueInfo[0]['FirstPrb']*12:(ueInfo[0]['NPrb'] + ueInfo[0]['FirstPrb'])*12])

    sysCfg = SystemConfig(**sysInfo)
    ueCfg = UeConfig(**ueInfo[0])
    myCfg = MyConfig(sysCfg, [ueCfg])
    puschCfg = MyPUSCHConfig(myCfg, slot_number=caseInfo['sf'], frame_number=caseInfo['sfn'])

    simulator = MySimulator(puschCfg)
    channel = OFDMChannel(channel_model=channel_model, resource_grid=simulator.resource_grid,
                                        add_awgn=False, normalize_channel=True, return_channel=True)
    
    r = simulator.ref(1)

    """Evaluate ls"""
    h_est, x_hat, llr_det, b_hat, crc_1 = simulator.rec(ueIQ)
    if crc_1:
        b_rec = b_hat
        c_rec = simulator.TB_Encoder(b_rec)
        ls_counter += 1

    """Evaluate nn"""
    preds = predict(_model, ueIQ, r[0:1])
    c_pred = tf.reshape(preds, [preds.shape[0], 1, -1])
    b_hat, crc_2 = simulator.TB_Decode(c_pred) 

    if crc_2:
        nn_counter += 1

    # Chỉ lấy tên file (bỏ đường dẫn)
    file_name_only = os.path.basename(filename)

    print(f'{n:3} {file_name_only:<28} | ls: {crc_1 == True} | nn: {crc_2 == True} | nSnr in flexRan: {auxInfo["nSNR(1)"]:7} | MCS: {puschCfg.tb.mcs_index:2} | NRB: {puschCfg.num_resource_blocks:4}')

print(len(filtered_dump_fail_files), ls_counter, nn_counter)
# Out:
#   0 dump_fail_sfn_525_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:     121 | MCS:  6 | NRB:  140
#   1 dump_fail_sfn_125_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      29 | MCS:  6 | NRB:  140
#   2 dump_fail_sfn_311_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -152    | MCS:  3 | NRB:  109
#   3 dump_fail_sfn_514_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     132 | MCS:  6 | NRB:  140
#   4 dump_fail_sfn_322_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -107    | MCS:  3 | NRB:  127
#   5 dump_fail_sfn_1020_sf_5      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan: -14     | MCS:  3 | NRB:  140
#   6 dump_fail_sfn_511_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:     132 | MCS:  6 | NRB:  140
#   7 dump_fail_sfn_801_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      79 | MCS:  7 | NRB:  117
#   8 dump_fail_sfn_144_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      35 | MCS:  7 | NRB:  140
#   9 dump_fail_sfn_519_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:     129 | MCS:  6 | NRB:  140
#  10 dump_fail_sfn_500_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     136 | MCS:  6 | NRB:  140
#  11 dump_fail_sfn_522_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:     129 | MCS:  6 | NRB:  140
#  12 dump_fail_sfn_316_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -114    | MCS:  3 | NRB:  130
#  13 dump_fail_sfn_493_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -52     | MCS:  3 | NRB:  140
#  14 dump_fail_sfn_363_sf_4       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:       6 | MCS:  9 | NRB:  140
#  15 dump_fail_sfn_155_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      35 | MCS:  7 | NRB:  140
#  16 dump_fail_sfn_495_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -43     | MCS:  3 | NRB:  140
#  17 dump_fail_sfn_506_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:     139 | MCS:  6 | NRB:  140
#  18 dump_fail_sfn_951_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -52     | MCS:  3 | NRB:  140
#  19 dump_fail_sfn_516_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     137 | MCS:  6 | NRB:  140
#  20 dump_fail_sfn_875_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -60     | MCS:  7 | NRB:  140
#  21 dump_fail_sfn_495_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -47     | MCS:  3 | NRB:  136
#  22 dump_fail_sfn_94_sf_4        | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -131    | MCS:  8 | NRB:  132
#  23 dump_fail_sfn_109_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -148    | MCS:  3 | NRB:  140
#  24 dump_fail_sfn_798_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -100    | MCS:  3 | NRB:  140
#  25 dump_fail_sfn_803_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -99     | MCS:  3 | NRB:  136
#  26 dump_fail_sfn_799_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -97     | MCS:  3 | NRB:  140
#  27 dump_fail_sfn_807_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -105    | MCS:  3 | NRB:  140
#  28 dump_fail_sfn_807_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -109    | MCS:  3 | NRB:  136
#  29 dump_fail_sfn_803_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -97     | MCS:  3 | NRB:  140
#  30 dump_fail_sfn_804_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -99     | MCS:  3 | NRB:  140
#  31 dump_fail_sfn_109_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -126    | MCS:  3 | NRB:  136
#  32 dump_fail_sfn_803_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -106    | MCS:  3 | NRB:  140
#  33 dump_fail_sfn_799_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -117    | MCS:  3 | NRB:  140
#  34 dump_fail_sfn_352_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -118    | MCS:  3 | NRB:  140
#  35 dump_fail_sfn_31_sf_14       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -79     | MCS:  6 | NRB:  136
#  36 dump_fail_sfn_373_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -105    | MCS:  3 | NRB:  140
#  37 dump_fail_sfn_460_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -89     | MCS:  3 | NRB:  126
#  38 dump_fail_sfn_275_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -126    | MCS:  3 | NRB:  136
#  39 dump_fail_sfn_50_sf_4        | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -80     | MCS:  6 | NRB:  125
#  40 dump_fail_sfn_275_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -160    | MCS:  3 | NRB:  140
#  41 dump_fail_sfn_374_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -130    | MCS:  3 | NRB:  140
#  42 dump_fail_sfn_39_sf_15       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      47 | MCS:  7 | NRB:  140
#  43 dump_fail_sfn_279_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -160    | MCS:  3 | NRB:  140
#  44 dump_fail_sfn_279_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -130    | MCS:  3 | NRB:  140
#  45 dump_fail_sfn_694_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      49 | MCS:  9 | NRB:  140
#  46 dump_fail_sfn_684_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      53 | MCS:  8 | NRB:  119
#  47 dump_fail_sfn_353_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -152    | MCS:  3 | NRB:  140
#  48 dump_fail_sfn_138_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      80 | MCS:  6 | NRB:  140
#  49 dump_fail_sfn_275_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -101    | MCS:  3 | NRB:  140
#  50 dump_fail_sfn_341_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -138    | MCS:  3 | NRB:  140
#  51 dump_fail_sfn_275_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -130    | MCS:  3 | NRB:  140
# 52 14 4

# %%
ls_counter = 0
nn_counter = 0

for n, filename in enumerate(filtered_dump_pass_files):
    cfg_path = f'{filename}_cfg.txt'
    data_path = f'{filename}_freq.bin'

    caseInfo, sysInfo, ueInfo, chcfg, auxInfo = config_parser(cfg_path)
    freqIQ = data_reader(data_path, (sysInfo['NRxAnt'], 14, sysInfo['BwpNRb']*12))
    ueIQ = tf.constant(freqIQ[None, None, :, :, ueInfo[0]['FirstPrb']*12:(ueInfo[0]['NPrb'] + ueInfo[0]['FirstPrb'])*12])

    sysCfg = SystemConfig(**sysInfo)   
    ueCfg = UeConfig(**ueInfo[0])
    myCfg = MyConfig(sysCfg, [ueCfg])
    puschCfg = MyPUSCHConfig(myCfg, slot_number=caseInfo['sf'], frame_number=caseInfo['sfn'])

    simulator = MySimulator(puschCfg)
    channel = OFDMChannel(channel_model=channel_model, resource_grid=simulator.resource_grid,
                                        add_awgn=False, normalize_channel=True, return_channel=True)
    
    r = simulator.ref(1)

    """Evaluate ls"""
    h_est, x_hat, llr_det, b_hat, crc_1 = simulator.rec(ueIQ)
    if crc_1:
        b_rec = b_hat
        c_rec = simulator.TB_Encoder(b_rec)
        ls_counter += 1

    """Evaluate nn"""
    preds = predict(_model, ueIQ, r[0:1])
    c_pred = tf.reshape(preds, [preds.shape[0], 1, -1])
    b_hat, crc_2 = simulator.TB_Decode(c_pred) 

    if crc_2:
        nn_counter += 1

    # Chỉ lấy tên file (bỏ đường dẫn)
    file_name_only = os.path.basename(filename)

    print(f'{n:3} {file_name_only:<28} | ls: {crc_1 == True} | nn: {crc_2 == True} | nSnr in flexRan: {auxInfo["nSNR(1)"]:7} | MCS: {puschCfg.tb.mcs_index:2} | NRB: {puschCfg.num_resource_blocks:4}')

print(len(filtered_dump_pass_files), ls_counter, nn_counter)
# Out:
#   0 dump_pass_sfn_496_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      15 | MCS:  3 | NRB:  140
#   1 dump_pass_sfn_1015_sf_4      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     162 | MCS:  6 | NRB:  140
#   2 dump_pass_sfn_1011_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     148 | MCS:  6 | NRB:  140
#   3 dump_pass_sfn_950_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -57     | MCS:  3 | NRB:  136
#   4 dump_pass_sfn_862_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -62     | MCS:  7 | NRB:  140
#   5 dump_pass_sfn_870_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -68     | MCS:  7 | NRB:  136
#   6 dump_pass_sfn_951_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -52     | MCS:  3 | NRB:  140
#   7 dump_pass_sfn_494_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      10 | MCS:  3 | NRB:  140
#   8 dump_pass_sfn_419_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:     127 | MCS:  3 | NRB:  130
#   9 dump_pass_sfn_951_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -51     | MCS:  3 | NRB:  140
#  10 dump_pass_sfn_910_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -43     | MCS:  8 | NRB:  119
#  11 dump_pass_sfn_869_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -56     | MCS:  7 | NRB:  136
#  12 dump_pass_sfn_78_sf_4        | ls: [[False]] | nn: [[False]] | nSnr in flexRan:     136 | MCS:  9 | NRB:  137
#  13 dump_pass_sfn_862_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -59     | MCS:  7 | NRB:  136
#  14 dump_pass_sfn_1011_sf_4      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     156 | MCS:  6 | NRB:  140
#  15 dump_pass_sfn_872_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -50     | MCS:  7 | NRB:  136
#  16 dump_pass_sfn_671_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -28     | MCS:  3 | NRB:  140
#  17 dump_pass_sfn_982_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      31 | MCS:  5 | NRB:  109
#  18 dump_pass_sfn_870_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -64     | MCS:  7 | NRB:  140
#  19 dump_pass_sfn_320_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      63 | MCS:  7 | NRB:  136
#  20 dump_pass_sfn_239_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      63 | MCS:  7 | NRB:  136
#  21 dump_pass_sfn_152_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      34 | MCS:  7 | NRB:  140
#  22 dump_pass_sfn_156_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      17 | MCS:  7 | NRB:  140
#  23 dump_pass_sfn_1020_sf_14     | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -16     | MCS:  3 | NRB:  136
#  24 dump_pass_sfn_937_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -48     | MCS:  3 | NRB:  136
#  25 dump_pass_sfn_839_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -33     | MCS:  3 | NRB:  136
#  26 dump_pass_sfn_949_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -57     | MCS:  3 | NRB:  136
#  27 dump_pass_sfn_788_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -55     | MCS:  3 | NRB:  136
#  28 dump_pass_sfn_164_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      20 | MCS:  8 | NRB:  129
#  29 dump_pass_sfn_840_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -39     | MCS:  3 | NRB:  140
#  30 dump_pass_sfn_1021_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       0 | MCS:  3 | NRB:  118
#  31 dump_pass_sfn_151_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      38 | MCS:  7 | NRB:  140
#  32 dump_pass_sfn_156_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      29 | MCS:  8 | NRB:  140
#  33 dump_pass_sfn_1012_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     149 | MCS:  6 | NRB:  140
#  34 dump_pass_sfn_495_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      11 | MCS:  3 | NRB:  140
#  35 dump_pass_sfn_874_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -58     | MCS:  7 | NRB:  136
#  36 dump_pass_sfn_240_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      61 | MCS:  7 | NRB:  140
#  37 dump_pass_sfn_407_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      74 | MCS:  5 | NRB:  140
#  38 dump_pass_sfn_1020_sf_4      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -27     | MCS:  3 | NRB:  140
#  39 dump_pass_sfn_910_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -49     | MCS:  8 | NRB:  119
#  40 dump_pass_sfn_870_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -60     | MCS:  7 | NRB:  130
#  41 dump_pass_sfn_840_sf_5       | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -29     | MCS:  3 | NRB:  140
#  42 dump_pass_sfn_124_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -89     | MCS:  3 | NRB:  140
#  43 dump_pass_sfn_1020_sf_15     | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan: -12     | MCS:  3 | NRB:  140
#  44 dump_pass_sfn_1011_sf_14     | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     151 | MCS:  6 | NRB:  136
#  45 dump_pass_sfn_164_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  8 | NRB:  132
#  46 dump_pass_sfn_415_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:     113 | MCS:  3 | NRB:  130
#  47 dump_pass_sfn_869_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -62     | MCS:  7 | NRB:  140
#  48 dump_pass_sfn_98_sf_14       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      35 | MCS:  5 | NRB:  109
#  49 dump_pass_sfn_495_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       8 | MCS:  3 | NRB:  140
#  50 dump_pass_sfn_1011_sf_15     | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     160 | MCS:  6 | NRB:  140
#  51 dump_pass_sfn_840_sf_14      | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -20     | MCS:  3 | NRB:  136
#  52 dump_pass_sfn_1015_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     158 | MCS:  6 | NRB:  140
#  53 dump_pass_sfn_144_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       1 | MCS:  7 | NRB:  140
#  54 dump_pass_sfn_154_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      35 | MCS:  7 | NRB:  109
#  55 dump_pass_sfn_2_sf_5         | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      53 | MCS:  6 | NRB:  106
#  56 dump_pass_sfn_891_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     125 | MCS:  3 | NRB:  118
#  57 dump_pass_sfn_875_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -62     | MCS:  7 | NRB:  136
#  58 dump_pass_sfn_320_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      61 | MCS:  7 | NRB:  140
#  59 dump_pass_sfn_241_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      76 | MCS:  7 | NRB:  109
#  60 dump_pass_sfn_950_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -45     | MCS:  3 | NRB:  140
#  61 dump_pass_sfn_1019_sf_15     | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan: -5      | MCS:  3 | NRB:  140
#  62 dump_pass_sfn_839_sf_15      | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -28     | MCS:  3 | NRB:  140
#  63 dump_pass_sfn_369_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      32 | MCS:  9 | NRB:  140
#  64 dump_pass_sfn_270_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       1 | MCS:  7 | NRB:  136
#  65 dump_pass_sfn_952_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -45     | MCS:  3 | NRB:  140
#  66 dump_pass_sfn_874_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -60     | MCS:  7 | NRB:  140
#  67 dump_pass_sfn_239_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      45 | MCS:  7 | NRB:  140
#  68 dump_pass_sfn_362_sf_15      | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      22 | MCS:  9 | NRB:  140
#  69 dump_pass_sfn_871_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -61     | MCS:  7 | NRB:  140
#  70 dump_pass_sfn_937_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -43     | MCS:  3 | NRB:  140
#  71 dump_pass_sfn_952_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -44     | MCS:  3 | NRB:  140
#  72 dump_pass_sfn_163_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      27 | MCS:  8 | NRB:  132
#  73 dump_pass_sfn_868_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -48     | MCS:  7 | NRB:  107
#  74 dump_pass_sfn_143_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      32 | MCS:  7 | NRB:  140
#  75 dump_pass_sfn_240_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      52 | MCS:  7 | NRB:  136
#  76 dump_pass_sfn_304_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      54 | MCS:  7 | NRB:  136
#  77 dump_pass_sfn_152_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      31 | MCS:  7 | NRB:  113
#  78 dump_pass_sfn_295_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      24 | MCS:  7 | NRB:  140
#  79 dump_pass_sfn_937_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -43     | MCS:  3 | NRB:  140
#  80 dump_pass_sfn_990_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:      19 | MCS:  5 | NRB:  109
#  81 dump_pass_sfn_951_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -44     | MCS:  3 | NRB:  136
#  82 dump_pass_sfn_840_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -48     | MCS:  3 | NRB:  140
#  83 dump_pass_sfn_368_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      39 | MCS:  9 | NRB:  140
#  84 dump_pass_sfn_870_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -63     | MCS:  7 | NRB:  140
#  85 dump_pass_sfn_494_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       3 | MCS:  3 | NRB:  140
#  86 dump_pass_sfn_1012_sf_4      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     154 | MCS:  6 | NRB:  137
#  87 dump_pass_sfn_817_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      77 | MCS:  6 | NRB:  135
#  88 dump_pass_sfn_270_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       2 | MCS:  7 | NRB:  137
#  89 dump_pass_sfn_781_sf_4       | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -34     | MCS:  3 | NRB:  140
#  90 dump_pass_sfn_872_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -51     | MCS:  7 | NRB:  136
#  91 dump_pass_sfn_542_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan: -10     | MCS:  7 | NRB:  136
#  92 dump_pass_sfn_566_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      26 | MCS:  7 | NRB:  136
#  93 dump_pass_sfn_563_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  7 | NRB:  136
#  94 dump_pass_sfn_568_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      70 | MCS:  7 | NRB:  140
#  95 dump_pass_sfn_718_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  8 | NRB:  137
#  96 dump_pass_sfn_717_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      32 | MCS:  8 | NRB:  137
#  97 dump_pass_sfn_729_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      36 | MCS:  8 | NRB:  137
#  98 dump_pass_sfn_9_sf_5         | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      72 | MCS:  6 | NRB:  140
#  99 dump_pass_sfn_719_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      32 | MCS:  8 | NRB:  133
# 100 dump_pass_sfn_718_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      30 | MCS:  8 | NRB:  133
# 101 dump_pass_sfn_292_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      21 | MCS:  8 | NRB:  111
# 102 dump_pass_sfn_593_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       4 | MCS:  3 | NRB:  136
# 103 dump_pass_sfn_566_sf_4       | ls: [[False]] | nn: [[ True]] | nSnr in flexRan:      26 | MCS:  7 | NRB:  140
# 104 dump_pass_sfn_730_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      31 | MCS:  8 | NRB:  137
# 105 dump_pass_sfn_530_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      77 | MCS:  7 | NRB:  140
# 106 dump_pass_sfn_660_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      75 | MCS:  7 | NRB:  134
# 107 dump_pass_sfn_417_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      12 | MCS:  7 | NRB:  140
# 108 dump_pass_sfn_531_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      31 | MCS:  7 | NRB:  136
# 109 dump_pass_sfn_731_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      42 | MCS:  8 | NRB:  133
# 110 dump_pass_sfn_913_sf_5       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan:       8 | MCS:  3 | NRB:  118
# 111 dump_pass_sfn_498_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      69 | MCS:  7 | NRB:  140
# 112 dump_pass_sfn_912_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      11 | MCS:  3 | NRB:  118
# 113 dump_pass_sfn_919_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       5 | MCS:  3 | NRB:  140
# 114 dump_pass_sfn_9_sf_15        | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      72 | MCS:  6 | NRB:  140
# 115 dump_pass_sfn_606_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      28 | MCS:  3 | NRB:  118
# 116 dump_pass_sfn_600_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       5 | MCS:  3 | NRB:  140
# 117 dump_pass_sfn_564_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      67 | MCS:  7 | NRB:  140
# 118 dump_pass_sfn_541_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      34 | MCS:  7 | NRB:  140
# 119 dump_pass_sfn_643_sf_4       | ls: [[ True]] | nn: [[False]] | nSnr in flexRan: -28     | MCS:  6 | NRB:  118
# 120 dump_pass_sfn_1001_sf_14     | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      36 | MCS:  7 | NRB:  136
# 121 dump_pass_sfn_715_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      32 | MCS:  8 | NRB:  133
# 122 dump_pass_sfn_660_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      12 | MCS:  7 | NRB:  136
# 123 dump_pass_sfn_521_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      31 | MCS:  7 | NRB:  140
# 124 dump_pass_sfn_542_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      79 | MCS:  7 | NRB:  137
# 125 dump_pass_sfn_659_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      60 | MCS:  7 | NRB:  140
# 126 dump_pass_sfn_716_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      30 | MCS:  8 | NRB:  137
# 127 dump_pass_sfn_643_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -9      | MCS:  6 | NRB:  118
# 128 dump_pass_sfn_41_sf_4        | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan: -26     | MCS:  3 | NRB:  140
# 129 dump_pass_sfn_920_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -44     | MCS:  3 | NRB:  136
# 130 dump_pass_sfn_568_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      67 | MCS:  7 | NRB:  140
# 131 dump_pass_sfn_521_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      73 | MCS:  7 | NRB:  140
# 132 dump_pass_sfn_731_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  8 | NRB:  137
# 133 dump_pass_sfn_542_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      82 | MCS:  7 | NRB:  140
# 134 dump_pass_sfn_606_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       7 | MCS:  3 | NRB:  118
# 135 dump_pass_sfn_692_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan: -2      | MCS:  6 | NRB:  136
# 136 dump_pass_sfn_660_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  7 | NRB:  140
# 137 dump_pass_sfn_520_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      70 | MCS:  7 | NRB:  140
# 138 dump_pass_sfn_1001_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      47 | MCS:  7 | NRB:  137
# 139 dump_pass_sfn_566_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      28 | MCS:  7 | NRB:  137
# 140 dump_pass_sfn_716_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      37 | MCS:  8 | NRB:  133
# 141 dump_pass_sfn_416_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      70 | MCS:  7 | NRB:  140
# 142 dump_pass_sfn_600_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      23 | MCS:  3 | NRB:  136
# 143 dump_pass_sfn_920_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:       3 | MCS:  3 | NRB:  140
# 144 dump_pass_sfn_606_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      10 | MCS:  3 | NRB:  114
# 145 dump_pass_sfn_720_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      28 | MCS:  8 | NRB:  137
# 146 dump_pass_sfn_909_sf_14      | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -24     | MCS:  3 | NRB:  136
# 147 dump_pass_sfn_692_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      73 | MCS:  6 | NRB:  140
# 148 dump_pass_sfn_9_sf_14        | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:       3 | MCS:  6 | NRB:  136
# 149 dump_pass_sfn_541_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      31 | MCS:  7 | NRB:  136
# 150 dump_pass_sfn_9_sf_4         | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      29 | MCS:  6 | NRB:  140
# 151 dump_pass_sfn_593_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      12 | MCS:  3 | NRB:  140
# 152 dump_pass_sfn_600_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      31 | MCS:  3 | NRB:  140
# 153 dump_pass_sfn_717_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      39 | MCS:  8 | NRB:  133
# 154 dump_pass_sfn_730_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      39 | MCS:  8 | NRB:  133
# 155 dump_pass_sfn_417_sf_5       | ls: [[False]] | nn: [[ True]] | nSnr in flexRan:       5 | MCS:  7 | NRB:  140
# 156 dump_pass_sfn_563_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      70 | MCS:  7 | NRB:  140
# 157 dump_pass_sfn_565_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      67 | MCS:  7 | NRB:  140
# 158 dump_pass_sfn_535_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      76 | MCS:  3 | NRB:  118
# 159 dump_pass_sfn_684_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      42 | MCS:  8 | NRB:  132
# 160 dump_pass_sfn_681_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      22 | MCS:  8 | NRB:  132
# 161 dump_pass_sfn_695_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      42 | MCS:  9 | NRB:  140
# 162 dump_pass_sfn_480_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      45 | MCS:  6 | NRB:  103
# 163 dump_pass_sfn_23_sf_4        | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -54     | MCS:  5 | NRB:  109
# 164 dump_pass_sfn_575_sf_14      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      39 | MCS:  7 | NRB:  136
# 165 dump_pass_sfn_576_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      18 | MCS:  7 | NRB:  136
# 166 dump_pass_sfn_576_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      48 | MCS:  7 | NRB:  137
# 167 dump_pass_sfn_576_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      45 | MCS:  7 | NRB:  140
# 168 dump_pass_sfn_19_sf_4        | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -60     | MCS:  5 | NRB:  109
# 169 dump_pass_sfn_696_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      30 | MCS:  9 | NRB:  140
# 170 dump_pass_sfn_482_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      26 | MCS:  6 | NRB:  140
# 171 dump_pass_sfn_479_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      35 | MCS:  6 | NRB:  128
# 172 dump_pass_sfn_455_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -75     | MCS:  3 | NRB:  126
# 173 dump_pass_sfn_61_sf_14       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -69     | MCS:  7 | NRB:  101
# 174 dump_pass_sfn_575_sf_15      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      47 | MCS:  7 | NRB:  140
# 175 dump_pass_sfn_449_sf_5       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     102 | MCS:  3 | NRB:  137
# 176 dump_pass_sfn_576_sf_4       | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:      45 | MCS:  7 | NRB:  140
# 177 dump_pass_sfn_455_sf_15      | ls: [[False]] | nn: [[ True]] | nSnr in flexRan: -21     | MCS:  3 | NRB:  126
# 178 dump_pass_sfn_460_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -30     | MCS:  3 | NRB:  126
# 179 dump_pass_sfn_452_sf_4       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -84     | MCS:  3 | NRB:  133
# 180 dump_pass_sfn_452_sf_15      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -44     | MCS:  3 | NRB:  133
# 181 102 105
