# %%
"""Run two below lines to get my_abc module"""
# !git clone https://github.com/thanhttttt/thanh.git
# !pip install -r /content/thanh/requirements.txt
"""Run two below lines to drive"""
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# 'Run two below lines to drive'

# %% [markdown]
# # Import

# %%
import os
if os.getenv("CUDA_VISIBLE_DEVICES") is None:
    gpu_num = 0 # Use "" to use the CPU
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


import sys
sys.path.append('../')
sys.path.append('/content/thanh/')
sys.path.append('../thanh/')
import sionna

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')

sionna.config.seed = 42 # Set seed for reproducible random number generation

# Load the required Sionna components
from sionna.nr.my_abc import *

# %%
def eval_on_field_data(model, dump_files):
    ls_counter = 0
    nn_counter = 0

    for n, filename in enumerate(dump_files):
        cfg_path = f'{filename}_cfg.txt'
        data_path = f'{filename}_freq.bin'

        caseInfo, sysInfo, ueInfo, _, auxInfo = config_parser(cfg_path)
        freqIQ = data_reader(data_path, (sysInfo['NRxAnt'], 14, sysInfo['BwpNRb']*12))
        ueIQ = tf.constant(freqIQ[None, None, :, :, ueInfo[0]['FirstPrb']*12:(ueInfo[0]['NPrb'] + ueInfo[0]['FirstPrb'])*12])

        sysCfg = SystemConfig(**sysInfo)
        ueCfg = UeConfig(**ueInfo[0])
        myCfg = MyConfig(sysCfg, [ueCfg])
        puschCfg = MyPUSCHConfig(myCfg, slot_number=caseInfo['sf'], frame_number=caseInfo['sfn'])

        simulator = MySimulator(puschCfg)
       
        r = simulator.ref(1)

        """Evaluate ls"""
        h_est, x_hat, llr_det, b_hat, crc_1 = simulator.rec(ueIQ)
        if crc_1:
            b_rec = b_hat
            c_rec = simulator.TB_Encoder(b_rec)
            ls_counter += 1

        """Evaluate nn"""
        preds = predict(model, ueIQ, r[0:1])
        c_soft = tf.reshape(preds, [preds.shape[0], 1, -1])
        b_hat, crc_2 = simulator.TB_Decode(c_soft) 

        if crc_2:
            nn_counter += 1

        # Chỉ lấy tên file (bỏ đường dẫn)
        file_name_only = os.path.basename(filename)

        print(f'{n:3} {file_name_only:<28} | ls: {crc_1 == True} | nn: {crc_2 == True} | nSnr in flexRan: {auxInfo["nSNR(1)"]:7} | MCS: {puschCfg.tb.mcs_index:2} | NRB: {puschCfg.num_resource_blocks:4}')

    print(len(dump_files), ls_counter, nn_counter)

# %%
# Đường dẫn đến thư mục chứa các file config
config_dir = "/workspaces/thanh/data_field/"

filtered_dump_fail_files = []
filtered_dump_pass_files = []

# Duyệt qua các file trong thư mục
for root, dirs, files in os.walk(config_dir):
    for name in files:
        filename = f'{root}/{name}'
        if filename.endswith("_cfg.txt"):  # Chỉ xét các file config
            file_path = os.path.join(config_dir, filename)
            
            with open(file_path, "r", encoding="utf-8") as file:
                content = file.read()

            DmrsTypeAPos = re.search(r"ue\{1\}\.DmrsTypeAPosition\s*=\s*(\d+)", content)
            DmrsAddPos = re.search(r"ue\{1\}\.DmrsAdditionalPosition\s*=\s*(\d+)", content)
            Mcs = re.search(r"ue\{1\}\.Mcs\s*=\s*(\d+)", content)
            Nrb = re.search(r"ue\{1\}\.NPrb\s*=\s*(\d+)", content)

            if DmrsTypeAPos and DmrsAddPos and Mcs and Nrb:
                DmrsTypeAPos = int(DmrsTypeAPos.group(1))
                DmrsAddPos = int(DmrsAddPos.group(1))
                Mcs = int(Mcs.group(1))
                Nrb = int(Nrb.group(1))

                # Kiểm tra điều kiện
                if DmrsTypeAPos == 3 and DmrsAddPos == 1 and Mcs in {3, 5, 6, 7, 8, 9} and Nrb >= 4:
                    filename = filename[:-len('_cfg.txt')]
                    if 'dump_fail' in filename:
                        filtered_dump_fail_files.append(filename)
                    elif 'dump_pass' in filename:
                        filtered_dump_pass_files.append(filename)

print("Các file thỏa mãn điều kiện:")
print('dump fail: ', len(filtered_dump_fail_files), 'files', '\ndump pass:', len(filtered_dump_pass_files), 'files')
# Out:
# Các file thỏa mãn điều kiện:
# dump fail:  52 files
# dump pass: 181 files

# %%
_model = CustomNeuralReceiver(training = False)
inputs = tf.zeros([1,48,14,18])
_model(inputs)
load_weights(_model, '../weight_4RB_batchsize_1024_186k_sample_dynamic_config_epoch120.pkl');
# Out:
# Loaded pretrained weights from ../weight_4RB_batchsize_1024_186k_sample_dynamic_config_epoch120.pkl

# %%
eval_on_field_data(_model, filtered_dump_pass_files)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742262346.600846    2287 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   0 dump_pass_sfn_496_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan:      15 | MCS:  3 | NRB:  140
#   1 dump_pass_sfn_1015_sf_4      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     162 | MCS:  6 | NRB:  140
#   2 dump_pass_sfn_1011_sf_5      | ls: [[ True]] | nn: [[ True]] | nSnr in flexRan:     148 | MCS:  6 | NRB:  140
#   3 dump_pass_sfn_950_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -57     | MCS:  3 | NRB:  136
#   4 dump_pass_sfn_862_sf_5       | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -62     | MCS:  7 | NRB:  140
#   5 dump_pass_sfn_870_sf_14      | ls: [[False]] | nn: [[False]] | nSnr in flexRan: -68     | MCS:  7 | NRB:  136
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2287/3949272223.py in ?()
# ----> 1 eval_on_field_data(_model, filtered_dump_pass_files)
#
# /tmp/ipykernel_2287/1379913520.py in ?(model, dump_files)
#      19
#      20         r = simulator.ref(1)
#      21
#      22         """Evaluate ls"""
# ---> 23         h_est, x_hat, llr_det, b_hat, crc_1 = simulator.rec(ueIQ)
#      24         if crc_1:
#      25             b_rec = b_hat
#      26             c_rec = simulator.TB_Encoder(b_rec)
#
# /workspaces/thanh/example_v3/../sionna/nr/my_abc.py in ?(self, y, snr_)
#     387         h_hat, err_var = self.Channel_Estimator([y, no_])
#     388         x_hat = self.Equalizer([y, h_hat, err_var, no_])
#     389         llr_det = self.Mimo_Detector([y, h_hat, err_var, no_])
#     390         llr_layer = self.Layer_Demapper(llr_det)
# --> 391         b_hat, tb_crc_status = self.TB_Decode(llr_layer)
#     392
#     393         return h_hat, x_hat, llr_det, b_hat, tb_crc_status
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/engine/base_layer.py in ?(self, *args, **kwargs)
#    1145
#    1146                 with autocast_variable.enable_auto_cast_variables(
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#    1152                     self._handle_activity_regularization(inputs, outputs)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# /workspaces/thanh/example_v3/../sionna/nr/tb_decoder.py in ?(self, inputs)
#     161         llr_cb = tf.reshape(llr_int,
#     162                         (-1, self._tb_encoder.num_tx, self._num_cbs, self._tb_encoder.ldpc_encoder.n))
#     163
#     164         # LDPC decoding
# --> 165         u_hat_cb = self._decoder(llr_cb)
#     166
#     167         # CB CRC removal (if relevant)
#     168         if self._cb_crc_decoder is not None:
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/engine/base_layer.py in ?(self, *args, **kwargs)
#    1145
#    1146                 with autocast_variable.enable_auto_cast_variables(
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#    1152                     self._handle_activity_regularization(inputs, outputs)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# /workspaces/thanh/example_v3/../sionna/fec/ldpc/decoding.py in ?(self, inputs)
#    1333         llr_5g = tf.concat([x1, z, x2], 1)
#    1334
#    1335         # and execute the decoder
#    1336         if not self._stateful:
# -> 1337             x_hat = super().call(llr_5g)
#    1338         else:
#    1339             x_hat,msg_vn = super().call([llr_5g, msg_vn]) # pylint: disable=used-before-assignment
#    1340
#
# /workspaces/thanh/example_v3/../sionna/fec/ldpc/decoding.py in ?(self, inputs)
#     951
#     952         # start decoding iterations
#     953         it = tf.constant(0)
#     954         # maximum_iterations required for XLA
# --> 955         _, msg_vn, _ = tf.while_loop(dec_stop,
#     956                                      dec_iter,
#     957                                      (llr_ch, msg_vn, it),
#     958                                      parallel_iterations=1,
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     237   ...   print(sess.run(x_out).shape)
#     238   (1000, 100)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(i, lv)
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#
# /workspaces/thanh/example_v3/../sionna/fec/ldpc/decoding.py in ?(llr_ch, msg_vn, it)
#     929             # permute edges into CN perspective
#     930             msg_cn = tf.gather(msg_vn.flat_values, self._cn_mask_tf, axis=None)
#     931
#     932             # check node update using the pre-defined function
# --> 933             msg_cn = self._cn_update(msg_cn)
#     934
#     935             # track exit decoding trajectory; requires all-zero cw?
#     936             if self._track_exit:
#
# /workspaces/thanh/example_v3/../sionna/fec/ldpc/decoding.py in ?(self, msg)
#     652
#     653         msg = tf.ragged.map_flat_values(tf.abs, msg) # remove sign
#     654
#     655         # apply _phi element-wise (does not support ragged Tensors)
# --> 656         msg = tf.ragged.map_flat_values(self._phi, msg)
#     657         msg_sum = tf.reduce_sum(msg, axis=1)
#     658
#     659         # TF2.9 does not support XLA for the addition of ragged tensors
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/ragged/ragged_functional_ops.py in ?(op, *args, **kwargs)
#     119         for partition_list in partition_lists
#     120     ]
#     121
#     122   # Delegate to `op`
# --> 123   op_output = op(*inner_args, **inner_kwargs)
#     124   # Check that the result has the expected shape (if known).
#     125   if flat_values_nrows is not None:
#     126     if not op_output.shape[:1].is_compatible_with([flat_values_nrows]):
#
# /workspaces/thanh/example_v3/../sionna/fec/ldpc/decoding.py in ?(self, x)
#     607         in [Ryan]_.
#     608         """
#     609         # the clipping values are optimized for tf.float32
#     610         x = tf.clip_by_value(x, clip_value_min=8.5e-8, clip_value_max=16.635532)
# --> 611         return tf.math.log(tf.math.exp(x)+1) - tf.math.log(tf.math.exp(x)-1)
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# /workspaces/thanh/.venv/lib/python3.11/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, name)
#    5621         _ctx, "Log", name, x)
#    5622       return _result
#    5623     except _core._NotOkStatusException as e:
#    5624       _ops.raise_from_not_ok_status(e, name)
# -> 5625     except _core._FallbackException:
#    5626       pass
#    5627     try:
#    5628       _result = _dispatcher_for_log(
#
# KeyboardInterrupt:
